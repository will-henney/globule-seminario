# %%
import numpy as np
from uncertainties import ufloat
from uncertainties import unumpy

# %%
''' Prueba 1 '''
x = [2,4,6,8,10]
y = [.1*i for i in x]
A = unumpy.uarray(x,y)
A
# Out:
# array([2.0+/-0.2, 4.0+/-0.4, 6.0+/-0.6000000000000001, 8.0+/-0.8,
#        10.0+/-1.0], dtype=object)

# %%
print('el primer elemento es ', A[0], 'su valor es', A[0].n, 'y su error es', A[0].s)
# Out:
# el primer elemento es  2.00+/-0.20 su valor es 2.0 y su error es 0.2

# %%
x1 = [1,4,5,8,60]
y1 = [.2*i for i in x]
A1 = unumpy.uarray(x1,y1)

# %%
A**2/A1
# Out:
# array([4.0+/-1.788854381999832, 4.0+/-1.1313708498984762,
#        7.2+/-2.2493519066611167, 8.0+/-2.2627416997969525,
#        1.6666666666666667+/-0.3379312516832344], dtype=object)

# %%
(A**2/A1)[0].s
# Out:
# 1.788854381999832

# %%
val = [(A**2/A1)[i].n for i in range(len(A**2/A1))]
err = [(A**2/A1)[i].s for i in range(len(A**2/A1))]

# %%
import matplotlib.pyplot as plt
fig, ax = plt.subplots()
ax.errorbar(x,val,xerr=err,linestyle='',marker='o')
# Out:
# <ErrorbarContainer object of 3 artists>
